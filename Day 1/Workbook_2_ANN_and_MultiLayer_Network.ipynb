# %% [markdown]
# # Workbook 2: ANN and Multi-Layer Neural Network
#
# Complete the exercises below to test your understanding of Module 2.
#
# ---

# %% [markdown]
# ## Section A: Conceptual Questions
#
# **Q1.** A single neuron computes: output = activation(w * x + b). How is this different from linear regression?

# %%
q1_answer = '''

'''
print(q1_answer)

# %% [markdown]
# **Q2.** Why are activation functions necessary? What would happen if we used no activation function in a 10-layer network?

# %%
q2_answer = '''

'''
print(q2_answer)

# %% [markdown]
# **Q3.** The XOR problem cannot be solved by a single neuron. Why not? What is special about XOR that requires a hidden layer?

# %%
q3_answer = '''

'''
print(q3_answer)

# %% [markdown]
# **Q4.** Explain backpropagation in your own words. What role does the chain rule play?

# %%
q4_answer = '''

'''
print(q4_answer)

# %% [markdown]
# ## Section B: Activation Functions -- Fill in the Blanks

# %%
import numpy as np

def sigmoid(z):
    return 1 / (1 + np.exp(-z))  # provided for reference

def relu(z):
    return np._____(0, z)  # FILL IN: which numpy function returns element-wise maximum?

def tanh(z):
    return np._____(z)  # FILL IN: which numpy function computes hyperbolic tangent?

# Test
z = np.array([-2, -1, 0, 1, 2])
print(f'Input:   {z}')
print(f'Sigmoid: {np.round(sigmoid(z), 4)}')
print(f'ReLU:    {relu(z)}')
print(f'Tanh:    {np.round(tanh(z), 4)}')

# %% [markdown]
# ## Section C: Single Neuron -- Fill in the Blanks
#
# Complete the forward pass and prediction for a single neuron.

# %%
import numpy as np

# Single neuron with 2 inputs
w = np.array([0.5, -0.3])
b = 0.1

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Input sample
x = np.array([2.0, 1.0])

# Step 1: Compute the linear combination
z = np.dot(_____, _____) + _____  # FILL IN: what gets dotted with what, plus what?

# Step 2: Apply activation
output = _____(z)  # FILL IN: which activation function for binary classification?

# Step 3: Make a prediction
prediction = 1 if output >= _____ else 0  # FILL IN: what is the standard threshold?

print(f'Linear combination (z): {z:.4f}')
print(f'After activation: {output:.4f}')
print(f'Prediction: {prediction}')

# %% [markdown]
# ## Section D: Keras Model Building -- Fill in the Blanks
#
# Complete the Keras model for classifying the Iris dataset (3 classes, 4 features).

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    # Hidden layer 1: 16 neurons, ReLU activation, input shape = 4 features
    keras.layers.Dense(_____, activation='_____', input_shape=(_____,)),

    # Hidden layer 2: 8 neurons, ReLU activation
    keras.layers.Dense(_____, activation='_____'),

    # Output layer: how many neurons for 3 classes? What activation?
    keras.layers.Dense(_____, activation='_____'),
])

model.compile(
    optimizer='adam',
    loss='_____',  # FILL IN: loss for integer labels with multiple classes
    metrics=['accuracy']
)

model.summary()

# %% [markdown]
# ## Section E: True or False
#
# **Q5.** For each statement, write True or False and a brief explanation.
#
# a) A neural network with 5 hidden layers but no activation functions can learn non-linear patterns.
#
# b) ReLU is preferred over sigmoid in hidden layers because it helps avoid the vanishing gradient problem.
#
# c) The softmax activation in the output layer is used for binary classification.
#
# d) Standardizing (scaling) input features has no effect on neural network training.
#
# e) Backpropagation computes gradients from the output layer back to the input layer.

# %%
q5_answer = '''
a) 
b) 
c) 
d) 
e) 
'''
print(q5_answer)

# %% [markdown]
# ## Section F: Connecting Concepts
#
# **Q6.** Fill in the comparison:
#
# | | Linear Regression (M1) | Single Neuron | Multi-Layer NN |
# |---|---|---|---|
# | Core equation | w*x + b | _____ | _____ |
# | Non-linearity | None | _____ | _____ |
# | Can solve XOR? | _____ | _____ | _____ |

# %%
q6_answer = '''

'''
print(q6_answer)
